# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Maltese_puppy.jpeg')
img.shape
# Out:
# (1382, 1843, 3)

# %%
plt.imshow(cv2.cvtColor(img.copy(), cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(img.copy(), cv2.COLOR_BGR2HSV))

# %%
plt.imshow(cv2.cvtColor(img.copy(), cv2.COLOR_BGR2HLS))
