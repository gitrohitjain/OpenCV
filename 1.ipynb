# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Maltese_puppy.jpeg')

# %%
fix = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix)

# %%
img = cv2.imread('Maltese_puppy.jpeg',0)
fix = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix)

# %%
a,b = fix.max(), fix.min()

# %%
fix = fix/255

# %%
plt.imshow(fix)

# %%
a,b = fix.max(), fix.min()
b,a
# Out:
# (0.0, 0.9411764705882353)

# %%
fix.shape
# Out:
# (1382, 1843, 3)

# %%
new =cv2.resize(fix,(1000,400))
plt.imshow(new)

# %%
new.shape
# Out:
# (400, 1000, 3)

# %%
new =cv2.resize(fix,(0,0),fix, 0.5,0.5)
plt.imshow(new)

# %%
flip = cv2.flip(fix,1)
plt.imshow(flip)

# %%
cv2.imwrite('yoyoyoy.jpg', flip)
# Out:
# True

# %%
fig = plt.figure(figsize=(25,25))
plt.imshow(flip)
